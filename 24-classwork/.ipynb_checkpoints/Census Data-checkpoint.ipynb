# %% [markdown]
# # Census Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 40)
# %matplotlib inline

# %%
# 2017 data
national_2017 = pd.read_csv("census/acs-2017-01-national.csv", encoding='latin-1').set_index('Geo_NAME')
divisions_2017 = pd.read_csv("census/acs-2017-02-divisions.csv", encoding='latin-1').set_index('Geo_NAME')
states_2017 = pd.read_csv("census/acs-2017-03-states.csv", encoding='latin-1').set_index('Geo_NAME')
cities_2017 = pd.read_csv("census/acs-2017-04-statistical-areas.csv", encoding='latin-1').set_index('Geo_NAME')
zips_2017 = pd.read_csv("census/acs-2017-05-zip-codes.csv", encoding='latin-1').set_index('Geo_NAME')
tracts_2017 = pd.read_csv("census/acs-2017-06-nyc-census-tracts.csv", encoding='latin-1').set_index('Geo_NAME')

# 2011 data
national_2011 = pd.read_csv("census/acs-2011-01-national.csv", encoding='latin-1').set_index('Geo_NAME')
divisions_2011 = pd.read_csv("census/acs-2011-02-divisions.csv", encoding='latin-1').set_index('Geo_NAME')
states_2011 = pd.read_csv("census/acs-2011-03-states.csv", encoding='latin-1').set_index('Geo_NAME')
cities_2011 = pd.read_csv("census/acs-2011-04-statistical-areas.csv", encoding='latin-1').set_index('Geo_NAME')
zips_2011 = pd.read_csv("census/acs-2011-05-zip-codes.csv", encoding='latin-1').set_index('Geo_NAME')
tracts_2011 = pd.read_csv("census/acs-2011-06-nyc-census-tracts.csv", encoding='latin-1').set_index('Geo_NAME')

# %% [markdown]
# We set the index to be the geographic area's name because it makes life a lot easier when reading rows.

# %%
divisions_2017.head(2)
# Out:
#                           Geo_FIPS Geo_GEOID                 Geo_QName  \
# Geo_NAME
# New England Division             1  03000US1      New England Division
# Middle Atlantic Division         2  03000US2  Middle Atlantic Division
#
#                          Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP Geo_FILEID  \
# Geo_NAME
# New England Division             us          30            0      ACSSF
# Middle Atlantic Division         us          30            0      ACSSF
#
#                           Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# Geo_NAME
# New England Division                68     NaN         NaN             1
# Middle Atlantic Division            69     NaN         NaN             2
#
#                           Geo_STATECE  Geo_STATE  Geo_COUNTY  Geo_COUSUB  \
# Geo_NAME
# New England Division              NaN        NaN         NaN         NaN
# Middle Atlantic Division          NaN        NaN         NaN         NaN
#
#                           Geo_PLACE  Geo_PLACESE  Geo_TRACT  Geo_BLKGRP  \
# Geo_NAME
# New England Division            NaN          NaN        NaN         NaN
# Middle Atlantic Division        NaN          NaN        NaN         NaN
#
#                           Geo_CONCIT  ...  SE_A07001_104  SE_A07001_105  \
# Geo_NAME                              ...
# New England Division             NaN  ...          59034          19500
# Middle Atlantic Division         NaN  ...         122641          93264
#
#                           SE_A07001_106  SE_A07001_107  SE_A07001_108  \
# Geo_NAME
# New England Division               2590           2976           1635
# Middle Atlantic Division          17249          24958          11279
#
#                           SE_A07001_109  SE_A07001_110  SE_A07001_111  \
# Geo_NAME
# New England Division             219222           7012           3887
# Middle Atlantic Division         951950          35404           8582
#
#                           SE_A07001_112  SE_A07001_113  SE_A07001_114  \
# Geo_NAME
# New England Division              85020           5720          46163
# Middle Atlantic Division          62846          19698         196541
#
#                           SE_A07001_115  SE_A07001_116  SE_A07001_117  \
# Geo_NAME
# New England Division              28038           6771          23377
# Middle Atlantic Division         265764         189982         120706
#
#                           SE_A07001_118  SE_A07001_119  SE_A07001_120  \
# Geo_NAME
# New England Division               3668           8037           1529
# Middle Atlantic Division          14638          24147          13642
#
#                           SE_A07001_121  SE_A07001_122  SE_A07001_123
# Geo_NAME
# New England Division              71846          70920            926
# Middle Atlantic Division          88101          86897           1204
#
# [2 rows x 218 columns]

# %% [markdown]
# # Exploring columns

# %% [markdown]
# Yes, we can select one column at a time, as always. Check the `acs-2017-data-dictionary.txt` file to understand the meaning of the columns. **You'll need to add `SE_` to them for them to work as column names.**
#
# ```
# A12001_001:     Population 25 Years and Over:
# ```

# %%
divisions_2017['SE_A12001_001']
# Out:
# Geo_NAME
# New England Division           10254551
# Middle Atlantic Division       28710461
# East North Central Division    31551468
# West North Central Division    14033406
# South Atlantic Division        43398781
# East South Central Division    12697387
# West South Central Division    25085758
# Mountain Division              15435244
# Pacific Division               35104588
# Name: SE_A12001_001, dtype: int64

# %% [markdown]
# Since we set the index, graphing is really easy and nice.

# %%
divisions_2017['SE_A12001_001'].plot(kind='bar')

# %% [markdown]
# If we want to move that into [DataWrapper](https://www.datawrapper.de/), we just copy it to the clipboard and paste it in.

# %%
divisions_2017['SE_A12001_001'].to_clipboard(header=True)

# %% [markdown]
# A few button-presses later and [there we go](https://datawrapper.dwcdn.net/loPmU/1/)!

# %% [markdown]
# # Multiple columns

# %% [markdown]
# But we can also take a range!
#
# ```
#       A12001_001:     Population 25 Years and Over:
#       A12001_002:     Population 25 Years and Over: Less than High School
#       A12001_003:     Population 25 Years and Over: High School Graduate (Includes Equivalency)
#       A12001_004:     Population 25 Years and Over: Some College
#       A12001_005:     Population 25 Years and Over: Bachelor's Degree
#       A12001_006:     Population 25 Years and Over: Master's Degree
#       A12001_007:     Population 25 Years and Over: Professional School Degree
#       A12001_008:     Population 25 Years and Over: Doctorate Degree
# ```

# %%
education = divisions_2017.loc[:, 'SE_A12001_002':'SE_A12001_008']
education
# Out:
#                              SE_A12001_002  SE_A12001_003  SE_A12001_004  \
# Geo_NAME
# New England Division                969730        2742746        2576892
# Middle Atlantic Division           3461203        8475670        6931720
# East North Central Division        3288342        9591905        9496180
# West North Central Division        1255191        3986126        4494023
# South Atlantic Division            5384043       12016253       12515192
# East South Central Division        1851520        4056576        3709054
# West South Central Division        4096759        6903696        7279664
# Mountain Division                  1745908        3812818        5135419
# Pacific Division                   5384418        7507822       10715171
#
#                              SE_A12001_005  SE_A12001_006  SE_A12001_007  \
# Geo_NAME
# New England Division               2268821        1210034         272020
# Middle Atlantic Division           5780691        2927506         707418
# East North Central Division        5718626        2534227         556990
# West North Central Division        2806754        1060954         254347
# South Atlantic Division            8201030        3735646         922134
# East South Central Division        1909452         834604         200641
# West South Central Division        4466256        1687403         387148
# Mountain Division                  3010117        1241322         280546
# Pacific Division                   7215321        2923112         812084
#
#                              SE_A12001_008
# Geo_NAME
# New England Division                214308
# Middle Atlantic Division            426253
# East North Central Division         365198
# West North Central Division         176011
# South Atlantic Division             624483
# East South Central Division         135540
# West South Central Division         264832
# Mountain Division                   209114
# Pacific Division                    546660

# %% [markdown]
# This is a terrible graph, but there you go

# %%
education.plot(kind='bar')

# %% [markdown]
# To move to DataWrapper, we do the same `.to_clipboard()` (we just don't need the `header=True` bit)

# %%
education.to_clipboard()

# %% [markdown]
# When you click "grouped bar chart," the graph you're looking at **doesn't look like the one above**. Click the "transpose" button and it will sort itself out and give you [this similar graphic](https://datawrapper.dwcdn.net/b5AMJ/1/).

# %% [markdown]
# # Joining multiple years together
#
# First we'll think about what we want. **Remember, we need to add `SE_` to our column names.**
#
# ```
#       A09003_001:     Average Commute to Work (In Min)
# ```

# %%
national_2017['SE_A09003_001']
# Out:
# Geo_NAME
# United States    26
# Name: SE_A09003_001, dtype: int64

# %%
national_2011['SE_A09003_001']
# Out:
# Geo_NAME
# United States    25
# Name: SE_A09003_001, dtype: int64

# %%
merged = pd.merge(national_2011['SE_A09003_001'],
                  national_2017['SE_A09003_001'],
                  left_index=True,
                  right_index=True,
                  suffixes=['_2011', '_2017'])
merged
# Out:
#                SE_A09003_001_2011  SE_A09003_001_2017
# Geo_NAME
# United States                  25                  26

# %%
merged.to_clipboard()

# %% [markdown]
# DataWrapper yells that we don't have enough data, but after a quick click of the "transpose" button [we're all set](https://datawrapper.dwcdn.net/riHYC/1/)

# %% [markdown]
# ## Joining multiple years and multiple columns
#
# Multiple years and multiple columns becomes a real chore, because DataWrapper doesn't like small multiples. Depending on your chart, you'll probably do something like this, though:

# %%
education_2011 = divisions_2011.loc[:, 'SE_A12001_002':'SE_A12001_008']
education_2011['year'] = 2011

education_2017 = divisions_2017.loc[:, 'SE_A12001_002':'SE_A12001_008']
education_2017['year'] = 2017

combined = pd.concat([education_2011, education_2017]).reset_index()
combined
# Out:
#                        Geo_NAME  SE_A12001_002  SE_A12001_003  SE_A12001_004  \
# 0          New England Division        1087163        2760470        2472168
# 1      Middle Atlantic Division        3770027        8597788        6576527
# 2   East North Central Division        3768240        9855641        8954257
# 3   West North Central Division        1409906        4051109        4201150
# 4       South Atlantic Division        5858061       11523084       11142451
# 5   East South Central Division        2175558        3953020        3364572
# 6   West South Central Division        4227508        6410616        6455836
# 7             Mountain Division        1788316        3593538        4633647
# 8              Pacific Division        5434156        7116017        9893673
# 9          New England Division         969730        2742746        2576892
# 10     Middle Atlantic Division        3461203        8475670        6931720
# 11  East North Central Division        3288342        9591905        9496180
# 12  West North Central Division        1255191        3986126        4494023
# 13      South Atlantic Division        5384043       12016253       12515192
# 14  East South Central Division        1851520        4056576        3709054
# 15  West South Central Division        4096759        6903696        7279664
# 16            Mountain Division        1745908        3812818        5135419
# 17             Pacific Division        5384418        7507822       10715171
#
#     SE_A12001_005  SE_A12001_006  SE_A12001_007  SE_A12001_008  year
# 0         2035428        1030571         247864         172906  2011
# 1         5115672        2464425         657369         355063  2011
# 2         5078970        2147691         526453         300476  2011
# 3         2483600         872405         232914         139324  2011
# 4         6988162        2943872         810808         495626  2011
# 5         1657435         677203         180254         110082  2011
# 6         3725557        1295377         335962         208081  2011
# 7         2561329         989008         242701         167004  2011
# 8         6206124        2353406         714302         450200  2011
# 9         2268821        1210034         272020         214308  2017
# 10        5780691        2927506         707418         426253  2017
# 11        5718626        2534227         556990         365198  2017
# 12        2806754        1060954         254347         176011  2017
# 13        8201030        3735646         922134         624483  2017
# 14        1909452         834604         200641         135540  2017
# 15        4466256        1687403         387148         264832  2017
# 16        3010117        1241322         280546         209114  2017
# 17        7215321        2923112         812084         546660  2017

# %%
combined.to_clipboard()

# %% [markdown]
# # And if you can't figure out how to reshape with pandas...
#
# You probably don't have THAT much data - typing into Excel with the right formatting and cutting and pasting can work wonders.
